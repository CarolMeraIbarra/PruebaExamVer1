# %%
# Importar graficas
import funcionesGraficas.crear_diagrama_barras_horizontales as diagramaBarra
import funcionesGraficas.crear_grafico_pastel as diagramaPastel
import funcionesGraficas.crear_histograma as diagramaHistograma
import funcionesGraficas.crear_ojiva as diagramaOjiva

# Importar funciones
import funciones.calcular_marcas_clase as marcaClase
import funciones.calcular_ancho_clase as anchoClase
import funciones.calcular_limites as limites
import funciones.calcular_numero_intervalos as numIntervalos
import funciones.calcular_rango as rangoo
import funciones.frecuencia_absoluta as frecAbsoluta
import funciones.frecuencia_acumulada as frecAcumulada
import funciones.frecuencia_relativa as frecRelativa
import funciones.frecuencia_absoluta_pe as frecAbsolutaP
import funciones.imprimir_resultados_corto as resultadosC
import funciones.imprimir_resultados_largo as resultadosL
import funciones.imprimir_tabla_corta as tablaC
import funciones.imprimir_tabla_larga as tablaL
import funciones.obtener_valores_extremos as valoresEx
import funciones.ordenar_datos as ordenarD


# Lista de datos
datos = ["Ramirez", "Rodrigez", "Hernandez", "Hernandez", "Rodrigez", "Rodrigez", "Gonzalez", "Gonzalez", 
         "Ramirez", "Hernandez", "Garcia", "Martinez", "Lopez", "Gonzalez", "Martinez", "Lopez", "Lopez", 
         "Gonzalez", "Gutierrez", "Martinez", "Gonzalez", "Rodrigez", "Perez", "Rodrigez", "Ramirez", "Sanchez",
         "Martinez", "Lopez", "Sanchez", "Garcia", "Rodrigez", "Hernandez","Gonzalez",  "Sanchez", "Perez", 
         "Rodrigez", "Lopez", "Martinez", "Flores", "Hernandez", "Perez", "Garcia", "Martinez", "Hernandez",
         "Sanchez", "Ramirez", "Garcia", "Gonzalez", "Garcia", "Flores", "Martinez", "Garcia", "Ramirez", "Gonzalez",
         "Hernandez", "Lopez", "Sanchez", "Martinez", "Martinez", "Perez", "Garcia", "Gonzalez", "Garcia", "Gutierrez",
         "Hernandez", "Martinez", "Garcia", "Hernandez", "Garcia", "Gonzalez", "Lopez", "Hernandez", "Rodrigez", 
         "Martinez", "Gonzalez", "Garcia", "Hernandez", "Ramirez", "Flores", "Hernandez", "Gutierrez", "Garcia", "Hernandez",
         "Gonzalez", "Garcia", "Garcia", "Flores", "Lopez", "Perez", "Sanchez", "Lopez", "Gutierrez", "Sanchez", "Rodrigez",
         "Hernandez", "Hernandez", "Perez", "Sanchez", "Lopez", "Martinez"]


# Ordenar los datos
datos_ordenados = ordenarD.ordenar_datos(datos)

# Calcular la frecuencia absoluta
categorias, frecuencias = frecAbsolutaP.frecuencia_absoluta_pe(datos_ordenados)

# Calcular la frecuencia relativa
frecuencias_relativas = frecRelativa.frecuencia_relativa(frecuencias)

# Calcular la frecuencia acumulada
frecuencias_acumuladas = frecAcumulada.frecuencia_acumulada(frecuencias)

# Imprimir los resultados cortos
resultadosC.imprimir_resultados_corto(datos_ordenados, frecuencias, frecuencias_relativas, frecuencias_acumuladas)

# Imprimir la tabla
tablaC.imprimir_tabla_corta(categorias, frecuencias, frecuencias_relativas, frecuencias_acumuladas)


# Crear gráfico de pastel
diagramaPastel.crear_grafico_pastel(categorias, frecuencias_relativas)

# Crear gráfico de barras horizontales
diagramaBarra.crear_diagrama_barras_horizontales(categorias, frecuencias)
# Out:
# Datos ordenados: ['Flores', 'Flores', 'Flores', 'Flores', 'Garcia', 'Garcia', 'Garcia', 'Garcia', 'Garcia', 'Garcia', 'Garcia', 'Garcia', 'Garcia', 'Garcia', 'Garcia', 'Garcia', 'Garcia', 'Garcia', 'Gonzalez', 'Gonzalez', 'Gonzalez', 'Gonzalez', 'Gonzalez', 'Gonzalez', 'Gonzalez', 'Gonzalez', 'Gonzalez', 'Gonzalez', 'Gonzalez', 'Gonzalez', 'Gutierrez', 'Gutierrez', 'Gutierrez', 'Gutierrez', 'Hernandez', 'Hernandez', 'Hernandez', 'Hernandez', 'Hernandez', 'Hernandez', 'Hernandez', 'Hernandez', 'Hernandez', 'Hernandez', 'Hernandez', 'Hernandez', 'Hernandez', 'Hernandez', 'Hernandez', 'Lopez', 'Lopez', 'Lopez', 'Lopez', 'Lopez', 'Lopez', 'Lopez', 'Lopez', 'Lopez', 'Lopez', 'Martinez', 'Martinez', 'Martinez', 'Martinez', 'Martinez', 'Martinez', 'Martinez', 'Martinez', 'Martinez', 'Martinez', 'Martinez', 'Martinez', 'Perez', 'Perez', 'Perez', 'Perez', 'Perez', 'Perez', 'Ramirez', 'Ramirez', 'Ramirez', 'Ramirez', 'Ramirez', 'Ramirez', 'Rodrigez', 'Rodrigez', 'Rodrigez', 'Rodrigez', 'Rodrigez', 'Rodrigez', 'Rodrigez', 'Rodrigez', 'Rodrigez', 'Sanchez', 'Sanchez', 'Sanchez', 'Sanchez', 'Sanchez', 'Sanchez', 'Sanchez', 'Sanchez']
# Frecuencia absoluta: [4, 14, 12, 4, 15, 10, 12, 6, 6, 9, 8]
# Frecuencia relativa: [4.0, 14.000000000000002, 12.0, 4.0, 15.0, 10.0, 12.0, 6.0, 6.0, 9.0, 8.0]
# Frecuencia acumulada: [4, 18, 30, 34, 49, 59, 71, 77, 83, 92, 100]
#
# Categoría      Frecuencia absoluta Frecuencia relativa (%)  Frecuencia acumulada (%)
# ----------     ------------------  ----------------------   ------------------------
# Flores         4                   4.00                     4.00
# Garcia         14                  14.00                    18.00
# Gonzalez       12                  12.00                    30.00
# Gutierrez      4                   4.00                     34.00
# Hernandez      15                  15.00                    49.00
# Lopez          10                  10.00                    59.00
# Martinez       12                  12.00                    71.00
# Perez          6                   6.00                     77.00
# Ramirez        6                   6.00                     83.00
# Rodrigez       9                   9.00                     92.00
# Sanchez        8                   8.00                     100.00
